# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned data
df = pd.read_csv('cleaned_data.csv')

# Univariate Analysis

# i. Summary statistics for numerical columns
print("Summary Statistics for Numerical Columns:")
print(df.describe())

# ii. Skewness and Variance
print("\nSkewness and Variance for Marks:")
print("Skewness for Marks: ", df['Marks'].skew())
print("Variance for Marks: ", df['Marks'].var())

print("\nSkewness and Variance for :")
print("Skewness for Marks: ", df['Attendance (%)'].skew())
print("Variance for Marks: ", df['Attendance (%)'].var())

print("\nSkewness and Variance for :")
print("Skewness for Marks: ", df['Age'].skew())
print("Variance for Marks: ", df['Age'].var())

# iii. Frequency distribution for categorical variables
print("\nFrequency Distribution for 'Status' column:")
print(df['Status'].value_counts())

print("\nFrequency Distribution for 'First Name' column:")
print(df['First Name'].value_counts())

print("\nFrequency Distribution for 'Subject' column:")
print(df['Subject'].value_counts())

print("\nFrequency Distribution for 'City' column:")
print(df['City'].value_counts())

# iv. Visualize Distributions using Histograms and Box Plots
# Histogram for 'Marks'
plt.figure(figsize=(10, 6))
sns.histplot(df['Marks'], kde=True)
plt.title('Distribution of Marks')
plt.show()

# Boxplot for 'Marks'
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Marks'])
plt.title('Boxplot for Marks')
plt.show()

# Histogram for 'Attendance (%)'
plt.figure(figsize=(10, 6))
sns.histplot(df['Attendance (%)'], kde=True)
plt.title('Distribution of Attendance (%)')
plt.show()

# Boxplot for 'Attendance (%)'
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Attendance (%)'])
plt.title('Boxplot for Attendance (%)')
plt.show()

# Histogram for 'Age'
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], kde=True)
plt.title('Distribution of Age')
plt.show()

# Boxplot for 'Marks'
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Age'])
plt.title('Boxplot for Age')
plt.show()

# Bivariate Analysis

# i. Correlation Matrix for Numerical Variables
corr_matrix = df[['Marks', 'Attendance (%)']].corr()
print("\nCorrelation Matrix for Marks and Attendance (%):")
print(corr_matrix)

corr_matrix1 = df[['Marks', 'Age']].corr()
print("\nCorrelation Matrix for Marks and Age:")
print(corr_matrix1)

# Visualizing correlation matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix between Marks and Attendance')
plt.show()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix1, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix between Marks and Age')
plt.show()

# ii. Scatter plot for Marks vs Attendance (%) and Marks vs Age
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Marks'], y=df['Attendance (%)'])
plt.title('Scatter Plot of Marks vs Attendance (%)')
plt.xlabel('Marks')
plt.ylabel('Attendance (%)')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Marks'], y=df['Age'])
plt.title('Scatter Plot of Marks vs Age')
plt.xlabel('Marks')
plt.ylabel('Age')
plt.show()

# iii. Bar plots for categorical vs numerical variables
# Bar plot for Marks by Status
plt.figure(figsize=(10, 6))
sns.barplot(x='Status', y='Marks', data=df)
plt.title('Average Marks by Status')
plt.show()

# Box plot for Attendance (%) by Status
plt.figure(figsize=(10, 6))
sns.boxplot(x='Status', y='Attendance (%)', data=df)
plt.title('Attendance Distribution by Status')
plt.show()

# Violin plot for Marks by Status
plt.figure(figsize=(10, 6))
sns.violinplot(x='Status', y='Marks', data=df)
plt.title('Distribution of Marks by Status')
plt.show()

#Bar plot for Marks by Subject
plt.figure(figsize=(10, 6))
sns.barplot(x='Subject', y='Marks', data=df)
plt.title('Average Marks by Subject')
plt.show()
 

# Multivariate Analysis

# i. Pairplot for multiple variables
sns.pairplot(df[['Marks', 'Attendance (%)']])
plt.show()

sns.pairplot(df[['Marks', 'Age']])
plt.show()

# ii. Heatmap to visualize correlations among multiple variables
# Correlation matrix for all numerical columns
corr_matrix_all = df[['Attendance (%)', 'Marks']].corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix_all, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap for All Numerical Variables')
plt.show()

# iii. Grouped comparisons based on 'Status' and 'Subject'
grouped_data1 = df.groupby('Status').agg({'Marks': 'mean', 'Attendance (%)': 'mean'}).reset_index()
print("\nGrouped Comparisons by Status:")
print(grouped_data1)

grouped_data2 = df.groupby('Subject').agg({'Marks': 'mean', 'Attendance (%)': 'mean'}).reset_index()
print("\nGrouped Comparisons by Subject:")
print(grouped_data2)


# Bar plot for grouped comparisons
plt.figure(figsize=(10, 6))
sns.barplot(x='Status', y='Marks', data=grouped_data1)
plt.title('Average Marks by Status')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='Subject', y='Marks', data=grouped_data2)
plt.title('Average Marks by Subject')
plt.show()

# Combined Data Analysis

# i. Relationship between 'Marks' and 'Attendance (%)' by 'Status'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Marks', y='Attendance (%)', hue='Status', data=df)
plt.title('Marks vs Attendance (%) by Status')
plt.show()

# ii. Violin plot to visualize the distribution of Marks and Attendance by Status
plt.figure(figsize=(10, 6))
sns.violinplot(x='Status', y='Marks', data=df, inner='quart')
plt.title('Distribution of Marks by Status')
plt.show()

plt.figure(figsize=(10, 6))
sns.violinplot(x='Status', y='Attendance (%)', data=df, inner='quart')
plt.title('Distribution of Attendance by Status')
plt.show()

# iii. Pairplot with 'Status' as the hue to observe combined relationships
sns.pairplot(df[['Marks', 'Attendance (%)', 'Status']], hue='Status')
plt.show()

# iv. Pairplot with 'Subject' as the hue to observe combined relationships
sns.pairplot(df[['Marks', 'Attendance (%)', 'Subject']], hue='Subject')
plt.show()

from IPython.core.display import display, HTML
display(HTML("<style>.output_wrapper, .output {height: auto !important; max-height: none !important;}</style>"))
# Out:
# Summary Statistics for Numerical Columns:
#        Student ID       Marks  Attendance (%)         Age
# count  150.000000  150.000000      150.000000  150.000000
# mean    75.500000   71.453333       77.886667   21.380000
# std     43.445368   19.717667       15.750375    1.998892
# min      1.000000   31.000000       30.000000   18.000000
# 25%     38.250000   56.000000       65.000000   20.000000
# 50%     75.500000   71.000000       80.000000   21.000000
# 75%    112.750000   85.000000       90.000000   23.000000
# max    150.000000  120.000000      120.000000   25.000000
#
# Skewness and Variance for Marks:
# Skewness for Marks:  -0.027213569365255742
# Variance for Marks:  388.7863982102909
#
# Skewness and Variance for :
# Skewness for Marks:  -0.4037348988485271
# Variance for Marks:  248.0743176733779
#
# Skewness and Variance for :
# Skewness for Marks:  -0.03570095064924774
# Variance for Marks:  3.9955704697986616
#
# Frequency Distribution for 'Status' column:
# Status
# Pass       94
# Fail       45
# Unknown    11
# Name: count, dtype: int64
#
# Frequency Distribution for 'First Name' column:
# First Name
# David      9
# James      7
# Olivia     6
# Matthew    6
# Sarah      6
#           ..
# Leo        1
# Kendra     1
# Ian        1
# Heather    1
# Ursula     1
# Name: count, Length: 92, dtype: int64
#
# Frequency Distribution for 'Subject' column:
# Subject
# Math                37
# History             32
# English             28
# Computer Science    27
# Science             24
# Unknown              2
# Name: count, dtype: int64
#
# Frequency Distribution for 'City' column:
# City
# New York        22
# Houston         21
# San Antonio     20
# Los Angeles     19
# Chicago         19
# San Diego       19
# Philadelphia    15
# Phoenix         12
# Unknown          3
# Name: count, dtype: int64
# Correlation Matrix for Marks and Attendance (%):
#                    Marks  Attendance (%)
# Marks           1.000000        0.318923
# Attendance (%)  0.318923        1.000000
#
# Correlation Matrix for Marks and Age:
#           Marks       Age
# Marks  1.000000 -0.065531
# Age   -0.065531  1.000000
# Grouped Comparisons by Status:
#     Status      Marks  Attendance (%)
# 0     Fail  49.822222       70.888889
# 1     Pass  81.436170       81.265957
# 2  Unknown  74.636364       77.636364
#
# Grouped Comparisons by Subject:
#             Subject      Marks  Attendance (%)
# 0  Computer Science  73.555556       81.000000
# 1           English  73.035714       77.750000
# 2           History  72.843750       81.875000
# 3              Math  70.810811       75.594595
# 4           Science  68.666667       73.458333
# 5           Unknown  44.000000       69.500000
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_13868\4031941282.py:208: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_wrapper, .output {height: auto !important; max-height: none !important;}</style>
